# %%
# !wget -nc https://lazyprogrammer.me/course_files/nlp/GoogleNews-vectors-negative300.bin.gz
# Out:
# --2022-11-27 19:20:52--  https://lazyprogrammer.me/course_files/nlp/GoogleNews-vectors-negative300.bin.gz
# Resolving lazyprogrammer.me (lazyprogrammer.me)... 104.21.23.210, 172.67.213.166, 2606:4700:3030::ac43:d5a6, ...
# Connecting to lazyprogrammer.me (lazyprogrammer.me)|104.21.23.210|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1647046227 (1.5G) [application/x-gzip]
# Saving to: ‘GoogleNews-vectors-negative300.bin.gz’
#
# GoogleNews-vectors- 100%[===================>]   1.53G  54.6MB/s    in 33s
#
# 2022-11-27 19:21:25 (47.4 MB/s) - ‘GoogleNews-vectors-negative300.bin.gz’ saved [1647046227/1647046227]

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/Machine\ Learning\:\ Natural\ Language\ Processing\ in\ Python
# Out:
# /content/drive/MyDrive/Machine Learning: Natural Language Processing in Python

# %%
! git init
# Out:
# Initialized empty Git repository in /content/drive/MyDrive/Machine Learning: Natural Language Processing in Python/.git/

# %%
# Out:
# Initialized empty Git repository in /content/.git/
